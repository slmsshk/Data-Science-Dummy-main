# %%
import pandas as pd

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Data
train=pd.read_csv('train.csv',index_col=0)
test=pd.read_csv('test.csv',index_col=0)
og=pd.read_csv('CrabAgePrediction.csv')

# %%
og.columns == train.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
# Testing Distribution

cols=test.columns

x=1
y=2
z=3
plt.figure(figsize=(10,15))

for col in cols:
#     print(x,y,z)

    plt.subplot(10,3,x)
    plt.hist(train[col],alpha=.5)
    plt.title(f'Train: {col}')
    x = z+1
    
    plt.subplot(10,3,y)
    plt.hist(test[col],color='red',alpha=.5)
    plt.title(f'Test: {col}')
    y =y+3
    
    plt.subplot(10,3,z)
    plt.hist(og[col],color='green',alpha=.8)
    plt.title(f'Real DS: {col}')
    z+=3
#     print(x,y)
#     plt.subplot(10,2,y)
# train.hist()

plt.tight_layout()
plt.show()

# %% [markdown]
# - Test and train set usual same distribution and close to real data set

# %%
rows_t,col_t=train.shape()
rows_tst,col_tst=test.shape()
rows_,col_t=train.shape()


print("Train")
print(f'Rows: {rows_t}\nColumns: {col_t}')

print("Test")
print(f'')
