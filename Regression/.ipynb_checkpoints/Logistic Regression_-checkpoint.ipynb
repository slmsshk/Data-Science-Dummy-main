# %% [markdown]
# # Logistic Regression

# %% [markdown]
# **logistic regression**. It's a fancy way of <span style="color:blue">predicting 🔮</span> whether something is a <span style="color:green">"yes" ✔️</span> or <span style="color:red">"no" ❌</span> kind of thing.<em>For example</em>, think of <span style="color:blue">predicting 🔮</span> whether someone will buy a new car or not based on their income and age.
#
# Now, the logistic regression tool works by looking at different factors(<i>features</i>) that might be important in making the prediction. These factors could be things like how much money 💰 someone makes or 👴how old they are👵. The tool then uses these factors to calculate the probability of someone buying a new car.
#
# But here's where things get really interesting. The tool doesn't just stop at the probability. It takes that probability and transforms it into a simple <span style="color:green">"yes" ✔️</span> or <span style="color:red">"no" ❌</span> answer. This is done using a special number called a threshold value. If the probability is greater than or equal to the threshold value, then it's a <span style="color:green">"yes" ✔️</span>. If it's less than the threshold value, then it's a <span style="color:red">"no" ❌</span>.
#
# Logistic regression is used in many different areas like <span style="color:green">healthcare 🏥</span>,<span style="color:#ffbf00"> marketing 📊</span>, and <span style="color:blue">social sciences 🌍</span>. It's a really powerful tool that can help people make predictions about all kinds of things. Even in machine learning, which is like teaching computers to learn, logistic regression is used to predict whether something belongs to one of two groups.
#
# So <span style="color:blue">𝔏𝔬𝔤𝔦𝔰𝔱𝔦𝔠 𝔯𝔢𝔤𝔯𝔢𝔰𝔰𝔦𝔬𝔫 🐱🐶🐾</span>- A tool that can predict whether something is a <span style="color:green">"yes" ✔️</span> or <span style="color:red">"no" ❌</span> kind of thing, using different factors to calculate a probability 🎲, and then transforming that probability 🎲 into a simple answer.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LinearRegression

X,Y=load_breast_cancer(return_X_y=True)

pred=LinearRegression().fit(X,Y).predict(X)

# %%
import matplotlib.pyplot as plt

# Create a list of colors for each point in the plot
colors = ['red' if val < 0 or val > 1 else 'green' for val in pred]

# Plot the data with the specified colors
plt.scatter(range(len(pred)), pred, c=colors)

# Show the plot
plt.show()

# %%
def logistic(n):
    return 1/(1+(2.71)**(-n))

# %%
l=[]
for i in range(-100,101):
    val=logistic(i)
    l.append(val)
    print(f'Input Value: {i}\nLogistic Function Value:{int(val)}')
    print(val>1 or val<0)
# Out:
# Input Value: -100
# Logistic Function Value:0
# False
# Input Value: -99
# Logistic Function Value:0
# False
# Input Value: -98
# Logistic Function Value:0
# False
# Input Value: -97
# Logistic Function Value:0
# False
# Input Value: -96
# Logistic Function Value:0
# False
# Input Value: -95
# Logistic Function Value:0
# False
# Input Value: -94
# Logistic Function Value:0
# False
# Input Value: -93
# Logistic Function Value:0
# False
# Input Value: -92
# Logistic Function Value:0
# False
# Input Value: -91
# Logistic Function Value:0
# False
# Input Value: -90
# Logistic Function Value:0
# False
# Input Value: -89
# Logistic Function Value:0
# False
# Input Value: -88
# Logistic Function Value:0
# False
# Input Value: -87
# Logistic Function Value:0
# False
# Input Value: -86
# Logistic Function Value:0
# False
# Input Value: -85
# Logistic Function Value:0
# False
# Input Value: -84
# Logistic Function Value:0
# False
# Input Value: -83
# Logistic Function Value:0
# False
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(l,color='red')
plt.title('Sigmoid')
plt.show()
