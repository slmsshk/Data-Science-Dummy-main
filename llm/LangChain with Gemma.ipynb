# %%
import keras_nlp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import keras_nlp
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\__init__.py:23
#      20 except ImportError:
#      21     pass
# ---> 23 from keras_nlp import layers
#      24 from keras_nlp import metrics
#      25 from keras_nlp import models
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\__init__.py:31
#      29 from keras_nlp.layers.modeling.transformer_decoder import TransformerDecoder
#      30 from keras_nlp.layers.modeling.transformer_encoder import TransformerEncoder
# ---> 31 from keras_nlp.layers.preprocessing.masked_lm_mask_generator import (
#      32     MaskedLMMaskGenerator,
#      33 )
#      34 from keras_nlp.layers.preprocessing.multi_segment_packer import (
#      35     MultiSegmentPacker,
#      36 )
#      37 from keras_nlp.layers.preprocessing.random_deletion import RandomDeletion
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\preprocessing\masked_lm_mask_generator.py:18
#      15 import tensorflow as tf
#      17 from keras_nlp.api_export import keras_nlp_export
# ---> 18 from keras_nlp.layers.preprocessing.preprocessing_layer import (
#      19     PreprocessingLayer,
#      20 )
#      21 from keras_nlp.utils.tensor_utils import assert_tf_text_installed
#      22 from keras_nlp.utils.tensor_utils import convert_to_ragged_batch
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\preprocessing\preprocessing_layer.py:16
#       1 # Copyright 2023 The KerasNLP Authors
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 import tensorflow as tf
# ---> 16 import tree
#      18 from keras_nlp.backend import config
#      19 from keras_nlp.backend import keras
#
# ModuleNotFoundError: No module named 'tree'

# %%
from keras.models import model_from_json

# Load the model architecture from config.json
with open('config.json', 'r') as f:
    model_config = f.read()

# Load the model weights from model.weights.h5
model = model_from_json(model_config)
model.load_weights('model.weights.h5')

# Now, your model is loaded and ready to use.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras\src\saving\serialization_lib.py:789, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     788 try:
# --> 789     mod = importlib.import_module(module)
#     790 except ModuleNotFoundError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
#     [... skipping similar frames: _find_and_load at line 1176 (2 times), _gcd_import at line 1204 (2 times), _call_with_frames_removed at line 241 (1 times), _find_and_load_unlocked at line 1126 (1 times)]
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\__init__.py:23
#      21     pass
# ---> 23 from keras_nlp import layers
#      24 from keras_nlp import metrics
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\__init__.py:31
#      30 from keras_nlp.layers.modeling.transformer_encoder import TransformerEncoder
# ---> 31 from keras_nlp.layers.preprocessing.masked_lm_mask_generator import (
#      32     MaskedLMMaskGenerator,
#      33 )
#      34 from keras_nlp.layers.preprocessing.multi_segment_packer import (
#      35     MultiSegmentPacker,
#      36 )
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\preprocessing\masked_lm_mask_generator.py:18
#      17 from keras_nlp.api_export import keras_nlp_export
# ---> 18 from keras_nlp.layers.preprocessing.preprocessing_layer import (
#      19     PreprocessingLayer,
#      20 )
#      21 from keras_nlp.utils.tensor_utils import assert_tf_text_installed
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras_nlp\layers\preprocessing\preprocessing_layer.py:16
#      15 import tensorflow as tf
# ---> 16 import tree
#      18 from keras_nlp.backend import config
#
# ModuleNotFoundError: No module named 'tree'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     model_config = f.read()
#       7 # Load the model weights from model.weights.h5
# ----> 8 model = model_from_json(model_config)
#       9 model.load_weights('model.weights.h5')
#      11 # Now, your model is loaded and ready to use.
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras\src\models\model.py:571, in model_from_json(json_string, custom_objects)
#     568 from keras.src.saving import serialization_lib
#     570 model_config = json.loads(json_string)
# --> 571 return serialization_lib.deserialize_keras_object(
#     572     model_config, custom_objects=custom_objects
#     573 )
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras\src\saving\serialization_lib.py:687, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     684     if obj is not None:
#     685         return obj
# --> 687 cls = _retrieve_class_or_fn(
#     688     class_name,
#     689     registered_name,
#     690     module,
#     691     obj_type="class",
#     692     full_config=config,
#     693     custom_objects=custom_objects,
#     694 )
#     696 if isinstance(cls, types.FunctionType):
#     697     return cls
#
# File c:\Users\Slmss\OneDrive\Desktop\Gemma\env\Lib\site-packages\keras\src\saving\serialization_lib.py:791, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     789     mod = importlib.import_module(module)
#     790 except ModuleNotFoundError:
# --> 791     raise TypeError(
#     792         f"Could not deserialize {obj_type} '{name}' because "
#     793         f"its parent module {module} cannot be imported. "
#     794         f"Full object config: {full_config}"
#     795     )
#     796 obj = vars(mod).get(name, None)
#     798 # Special case for keras.metrics.metrics
#
# TypeError: Could not deserialize class 'GemmaBackbone' because its parent module keras_nlp.src.models.gemma.gemma_backbone cannot be imported. Full object config: {'module': 'keras_nlp.src.models.gemma.gemma_backbone', 'class_name': 'GemmaBackbone', 'config': {'name': 'gemma_backbone', 'trainable': True, 'vocabulary_size': 256000, 'num_layers': 18, 'num_query_heads': 8, 'num_key_value_heads': 1, 'hidden_dim': 2048, 'intermediate_dim': 32768, 'head_dim': 256, 'layer_norm_epsilon': 1e-06, 'dropout': 0}, 'registered_name': 'keras_nlp>GemmaBackbone', 'assets': [], 'weights': 'model.weights.h5'}
