# %%
from scipy import stats
import numpy as np
import pandas as pd

# %%
from PIL import Image
import PIL,cv2
import matplotlib.pyplot as plt

# %%
im=Image.open('download.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=236x512>

# %%
hist=im.histogram()
plt.hist(hist)
plt.show()

# %%
img_array=np.array(im)
img_array
# Out:
# array([[[202, 149, 133],
#         [197, 147, 131],
#         [182, 139, 110],
#         ...,
#         [136, 128, 175],
#         [154, 148, 196],
#         [145, 140, 194]],
#
#        [[197, 140, 124],
#         [191, 136, 121],
#         [177, 127, 100],
#         ...,
#         [142, 127, 167],
#         [151, 141, 183],
#         [143, 133, 181]],
#
#        [[199, 143, 130],
#         [193, 139, 126],
#         [187, 134, 112],
#         ...,
#         [163, 147, 184],
#         [167, 155, 195],
#         [159, 144, 193]],
#
#        ...,
#
#        [[181, 193, 148],
#         [177, 187, 144],
#         [174, 184, 139],
#         ...,
#         [137, 129, 145],
#         [149, 143, 152],
#         [143, 143, 152]],
#
#        [[187, 191, 152],
#         [183, 186, 148],
#         [179, 183, 142],
#         ...,
#         [162, 148, 164],
#         [176, 167, 175],
#         [173, 170, 175]],
#
#        [[188, 192, 171],
#         [185, 187, 167],
#         [180, 184, 161],
# ...

# %%
img_array.shape
# Out:
# (512, 236, 3)

# %%
len(img_array)
# Out:
# 512

# %%
for i in range(len(img_array)):
    if i<15:
        plt.subplot(3,5,i+1)
        plt.imshow(img_array[i])
        plt.show()

# %%
# plt.figure(dpi=2000)
plt.imshow(img_array[4:90]*2)
